# %% [markdown]
# <a href="https://colab.research.google.com/github/paishowstopper/TSAI/blob/main/EVA5/Capstone/EVA5_Capstone_Round_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/longcw/RoIAlign.pytorch -q

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %%capture
# %cd Capstone/
# !mkdir midas
# %cd midas
# !wget https://github.com/intel-isl/MiDaS/releases/download/v2_1/model-f6b98070.pt
# %cd ..

# %%
# !mkdir data
# !cp -r '/content/gdrive/MyDrive/EVA_Session_13/data/customdata.zip' '/content/Capstone/data'
# %cd data
# !unzip customdata.zip
# %cd ..
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: customdata/images/Jimg098.jpg
#   inflating: customdata/images/Jimg099.jpg
#   inflating: customdata/images/Jimg100.jpg
#   inflating: customdata/images/Jimg101.jpg
#   inflating: customdata/images/Jimg102.jpg
#   inflating: customdata/images/Jimg103.jpg
#   inflating: customdata/images/Jimg104.jpg
#   inflating: customdata/images/Jimg105.jpg
#   inflating: customdata/images/Jimg106.jpg
#   inflating: customdata/images/Jimg107.jpg
#   inflating: customdata/images/Jimg108.jpg
#   inflating: customdata/images/Jimg109.jpg
#   inflating: customdata/images/Jimg110.jpg
#   inflating: customdata/images/Jimg111.jpg
#   inflating: customdata/images/Jimg112.jpg
#   inflating: customdata/images/Jimg113.jpg
#   inflating: customdata/images/Jimg114.jpg
#   inflating: customdata/images/Jimg115.jpg
#   inflating: customdata/images/Jimg116.jpg
#   inflating: customdata/images/Jimg117.jpg
#   inflating: customdata/images/Jimg118.jpg
# ...

# %%
# !cp -r '/content/gdrive/MyDrive/planercnn/checkpoint/planercnn_normal_warping_refine' '.'

# %%
# %matplotlib inline
from training.train import train
loss = train(plane_args,
             yolo_args,
             midas_args,
             1,1,1,
             resume_train=False,
             model_path='/content/gdrive/MyDrive/EVA_Capstone/')
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# use_pretrained True
# path midas/model-f6b98070.pt
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# ...
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 1056 layers, 2.37595e+08 parameters, 2.37484e+08 gradients
# Caching labels (3161 found, 4 missing, 38 empty, 0 duplicate, for 3203 images): 100%|██████████| 3203/3203 [00:00<00:00, 6925.74it/s]
# Caching images (1.8GB): 100%|██████████| 3203/3203 [00:19<00:00, 160.83it/s]
# Caching labels (303 found, 8 missing, 7 empty, 0 duplicate, for 318 images): 100%|██████████| 318/318 [00:00<00:00, 6887.87it/s]
# ...
