# %% [markdown]
# <a href="https://colab.research.google.com/github/paishowstopper/TSAI/blob/main/EVA5/Session14/MiDaS/Session14_MiDaS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd 'drive/MyDrive/MiDaS'
# Out:
# /content/drive/MyDrive/MiDaS

# %%
# !ls
# Out:
# Dockerfile  LICENSE  model-f6b98070.pt	      __pycache__  run.py
# hubconf.py  midas    model-small-70d6b9c8.pt  README.md    tf
# input	    mobile   output		      ros	   utils.py

# %%
# !python run.py
# Out:
# initialize
# device: cuda
# Loading weights:  model-f6b98070.pt
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# 100% 340M/340M [00:04<00:00, 73.4MB/s]
# start processing
#   processing input/Gimage_90.jpg (1/3590)
#   processing input/PImage35.jpg (2/3590)
#   processing input/N19.jpg (3/3590)
#   processing input/PImage21.jpg (4/3590)
#   processing input/Aimg_054.jpg (5/3590)
#   processing input/Bimg_91.jpg (6/3590)
#   processing input/f7a9e2db52.jpg (7/3590)
#   processing input/majdoor_76.jpg (8/3590)
#   processing input/Aimg_040.jpg (9/3590)
#   processing input/images (61).jpg (10/3590)
#   processing input/Aimg_055.jpg (11/3590)
#   processing input/Gimage_85.jpg (12/3590)
#   processing input/PImage34.jpg (13/3590)
# ...

# %%
cd output
# Out:
# /content/drive/My Drive/MiDaS/output

# %%
# !ls
# Out:
# '01-prince-boots - Copy.pfm'
# '01-prince-boots - Copy.png'
#  026f0ffddc.pfm
#  026f0ffddc.png
#  032620_LS_covid-masks_inline-680.pfm
#  032620_LS_covid-masks_inline-680.png
#  046acbc8e1.pfm
#  046acbc8e1.png
# '050bdc8229cf18030e2d8a266dd334af84-23-chelsea-boots.rsquare.w1200 - Copy.pfm'
# '050bdc8229cf18030e2d8a266dd334af84-23-chelsea-boots.rsquare.w1200 - Copy.png'
#  051fa0f9fd.pfm
#  051fa0f9fd.png
# '05a207d8-6378-43a2-9d1e-431ca7a944e4-unnamed - Copy.pfm'
# '05a207d8-6378-43a2-9d1e-431ca7a944e4-unnamed - Copy.png'
#  088b63b347a4e40f0777df612ebe490a.pfm
#  088b63b347a4e40f0777df612ebe490a.png
#  0983a70ffe.pfm
#  0983a70ffe.png
#  0b59d3bd16.pfm
#  0b59d3bd16.png
#  101.pfm
#  101.png
#  102.pfm
#  102.png
#  103.pfm
#  103.png
#  104.pfm
#  104.png
#  105.pfm
#  105.png
#  106.pfm
#  106.png
#  107.pfm
#  107.png
#  10e3431da9.pfm
#  10e3431da9.png
#  10.pfm
#  10.png
#  110.pfm
#  110.png
#  1110f7133f.pfm
#  1110f7133f.png
#  1119a27d1c.pfm
#  1119a27d1c.png
# ...
